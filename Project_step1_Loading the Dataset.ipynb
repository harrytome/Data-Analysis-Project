# %%
import os
import glob
import pandas as pd

# %%
os.chdir(r"C:\Users\ACER\Documents\Data-Analysis-Project-main")

# %%
extension = 'csv'

# %%
path = (r"C:\Users\ACER\Documents\Data-Analysis-Project-main")

# %%
files = glob.glob(path + '/*.csv')

# %%
files
# Out:
# ['C:\\Users\\ACER\\Documents\\Data-Analysis-Project-main\\Abuja_Branch.csv',
#  'C:\\Users\\ACER\\Documents\\Data-Analysis-Project-main\\Lagos_Branch.csv',
#  'C:\\Users\\ACER\\Documents\\Data-Analysis-Project-main\\Port_Harcourt_Branch.csv']

# %%
All = []

# %%
for f in files:
    temp_df = pd.read_csv(f)
    All.append(temp_df)
    print(f'Successfully created dataframe for {f} with shape {temp_df.shape}')
# Out:
# Successfully created dataframe for C:\Users\ACER\Documents\Data-Analysis-Project-main\Abuja_Branch.csv with shape (332, 17)
# Successfully created dataframe for C:\Users\ACER\Documents\Data-Analysis-Project-main\Lagos_Branch.csv with shape (340, 17)
# Successfully created dataframe for C:\Users\ACER\Documents\Data-Analysis-Project-main\Port_Harcourt_Branch.csv with shape (328, 17)

# %%
df = pd.concat(All, axis=0)

# %%
df.to_csv(r'C:\Users\ACER\Documents\Data-Analysis-Project-main\All_Branches.csv')

# %%
pd.read_csv(r'C:\Users\ACER\Documents\Data-Analysis-Project-main\All_Branches.csv')
# Out:
#      Unnamed: 0   Invoice ID Branch           City Customer type  Gender  \
# 0             0  692-92-5582      B          Abuja        Member  Female
# 1             1  351-62-0822      B          Abuja        Member  Female
# 2             2  529-56-3974      B          Abuja        Member    Male
# 3             3  299-46-1805      B          Abuja        Member  Female
# 4             4  319-50-3348      B          Abuja        Normal  Female
# ..          ...          ...    ...            ...           ...     ...
# 995         323  148-41-7930      C  Port Harcourt        Normal    Male
# 996         324  189-40-5216      C  Port Harcourt        Normal    Male
# 997         325  267-62-7380      C  Port Harcourt        Member    Male
# 998         326  652-49-6720      C  Port Harcourt        Member  Female
# 999         327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# ...
